# %%
from gensim.models.ldamodel import LdaModel
import gensim.corpora as corpora
import pandas as pd
from gensim.models import Word2Vec
import tensorflow as tf
import numpy as np

# %% [markdown]
# ## Sequence labelling model

# %%
MAX_SEQ_LEN = 64
t2i_dict = {'c': 1, 'o': 2, 'b': 3, 'a': 4}

# %%
def word2ind_with_w2v(fname, word_set):
  sentences = []
  tags = []
  with open(fname, 'r', encoding='utf8') as fin:
    content = fin.read().replace('\n\n', '')
    content_list = content.split('\n')
    for line in content_list:
      line_word_seg = []
      line_tag_seg = []
      for phrase in line.split(' '):
        if len(phrase) < 3: continue
        words, tag = phrase.split('/')
        words = words.split('_')
        tag = [t2i_dict[tag]] * len(words)
        words = [word_set.index(word) for word in words]
        line_word_seg.extend(words)
        line_tag_seg.extend(tag)
      if len(line_word_seg) < MAX_SEQ_LEN:
        line_word_seg.extend([0] * (MAX_SEQ_LEN - len(line_word_seg)))
        line_tag_seg.extend([0] * (MAX_SEQ_LEN - len(line_tag_seg)))
      elif len(line_word_seg) > MAX_SEQ_LEN:
        line_word_seg = line_word_seg[: MAX_SEQ_LEN]
        line_tag_seg = line_tag_seg[: MAX_SEQ_LEN]
      sentences.append(line_word_seg)
      tags.append(line_tag_seg)
  return sentences, tags

# %%
def get_t2i_map(fname, preserve_zero=True):
  word_list = []

  with open(fname, 'r', encoding='utf8') as fin:
    content = fin.read().replace('\n\n', '')
    content_list = content.split('\n')
    for line in content_list:
      for phrase in line.split(' '):
        if len(phrase) < 3: continue
        words, tag = phrase.split('/')
        words = words.split('_')
        word_list.extend(words)
  word_set = set(word_list)
  word_set = sorted(word_set)

  if preserve_zero:
    word_set.insert(0, '<UNK>')

  return word_set

# %%
# word_set = get_t2i_map('/home/lian/data/nlp/datagrand_info_extra/train.txt')
len(word_set)
# Out:
# 4549

# %%
sentences, tags = word2ind_with_w2v('/home/lian/data/nlp/datagrand_info_extra/train.txt', word_set)

# %%
import numpy as np
sentences = np.array(sentences)
tags = np.array(tags)

# %%
sentences.shape, tags.shape
# Out:
# ((17000, 64), (17000, 64))

# %%
tf.reset_default_graph()

# %%
def data_iterate(X, y, batch_size):
  """

  Args:
    X:
    y:
    batch_size:

  Returns:

  """
  # Split dataset to train and test.
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)
  train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
  train_dataset = train_dataset.batch(batch_size)

  dev_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test))
  dev_dataset = dev_dataset.batch(batch_size)

  test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test))
  test_dataset = test_dataset.batch(batch_size)

  # A reinitializable iterator
  iterator = tf.data.Iterator.from_structure(train_dataset.output_types, train_dataset.output_shapes)

  train_initializer = iterator.make_initializer(train_dataset)
  dev_initializer = iterator.make_initializer(dev_dataset)
  test_initializer = iterator.make_initializer(test_dataset)

  return train_initializer, dev_initializer, test_initializer, iterator

# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf

train_initializer, dev_initializer, test_initializer, iterator = data_iterate(sentences, tags, 10)

# %%
x, y = iterator.get_next()

# %%
embedding = tf.Variable(tf.random_normal([4550, 20]), dtype=tf.float32)
inputs = tf.nn.embedding_lookup(embedding, x + 1)

# %%
from tensorflow.contrib import rnn
def lstm_cell(rnn_units, keep_prob, reuse=False):
  if reuse:
    tf.get_variable_scope.reuse_variables()
  cell = rnn.LSTMCell(rnn_units)
  return rnn.DropoutWrapper(cell, output_keep_prob=keep_prob)

# %%
cell_fw = [lstm_cell(128, 1) for _ in range(1)]
cell_bw = [lstm_cell(128, 1) for _ in range(1)]
inputs = tf.unstack(inputs, 64, axis=1)
output, _, _ = tf.contrib.rnn.stack_bidirectional_rnn(cell_fw, cell_bw, inputs=inputs, dtype=tf.float32)

# %%
output = tf.stack(output, axis=1)
print(output.shape)
output = tf.reshape(output, [-1, 128 * 2])
# Out:
# (?, 64, 256)

# %%
tf.nn.embedding_lookup(embedding, x + 1).shape, output.shape
# Out:
# (TensorShape([Dimension(None), Dimension(64), Dimension(20)]),
#  TensorShape([Dimension(None), Dimension(256)]))

# %%
len(tf.unstack(tf.nn.embedding_lookup(embedding, x + 1), axis=1)), output.shape
# Out:
# (64, TensorShape([Dimension(None), Dimension(256)]))

# %%
logits = tf.keras.layers.Dense(5)(output)
y_predict = tf.cast(tf.argmax(logits, axis=1), tf.int32)
print('Output Y', y_predict)
# Out:
# Output Y Tensor("Cast:0", shape=(?,), dtype=int32)

# %%
# Reshape y_label
y_label_reshape = tf.cast(tf.reshape(y, [-1]), tf.int32)
# Prediction
correct_prediction = tf.equal(y_predict, y_label_reshape)
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
# Loss
cross_entropy = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(
    labels=y_label_reshape, logits=tf.cast(logits, tf.float32)))

# Train
train = tf.train.AdamOptimizer(0.001).minimize(cross_entropy)

# %%
with tf.Session() as sess:
    sess.run(tf.initialize_all_variables())
    for epoch in range(100):
    #     tf.train.global_step(sess, global_step_tensor=global_step)
        # Train
        sess.run(train_initializer)
        for step in range(200):
            loss, acc, _ = sess.run([cross_entropy, accuracy, train])
            # Print log
            if step % 10 == 0:
                print('Step', step, 'Train Loss', loss, 'Accuracy', acc)

        if epoch % 2 == 0:
            # Dev
            sess.run(dev_initializer)
            for step in range(5):
                if step % 20 == 0:
                    print('Dev Accuracy', sess.run(accuracy), 'Step', step)
# Out:
# Step 0 Train Loss 1.6643097 Accuracy 0.125
# Step 10 Train Loss 0.65001404 Accuracy 0.8859375
# Step 20 Train Loss 0.29254133 Accuracy 0.94375
# Step 30 Train Loss 0.5746679 Accuracy 0.8515625
# Step 40 Train Loss 0.41754866 Accuracy 0.8921875
# Step 50 Train Loss 0.24996157 Accuracy 0.94375
# Step 60 Train Loss 0.2578134 Accuracy 0.9375
# Step 70 Train Loss 0.4252585 Accuracy 0.8859375
# Step 80 Train Loss 0.48681563 Accuracy 0.884375
# Step 90 Train Loss 0.35601166 Accuracy 0.9078125
# Step 100 Train Loss 0.3305379 Accuracy 0.921875
# Step 110 Train Loss 0.16293706 Accuracy 0.96875
# Step 120 Train Loss 0.39690804 Accuracy 0.88125
# Step 130 Train Loss 0.3899981 Accuracy 0.9078125
# Step 140 Train Loss 0.37138325 Accuracy 0.9203125
# Step 150 Train Loss 0.22349629 Accuracy 0.9578125
# Step 160 Train Loss 0.26988006 Accuracy 0.9296875
# Step 170 Train Loss 0.3218057 Accuracy 0.9125
# Step 180 Train Loss 0.3206797 Accuracy 0.925
# Step 190 Train Loss 0.3426709 Accuracy 0.8953125
# Dev Accuracy 0.9375 Step 0
# Step 0 Train Loss 0.48079214 Accuracy 0.853125
# Step 10 Train Loss 0.43014726 Accuracy 0.8921875
# Step 20 Train Loss 0.2177196 Accuracy 0.9484375
# Step 30 Train Loss 0.37881774 Accuracy 0.90625
# Step 40 Train Loss 0.36078316 Accuracy 0.8921875
# Step 50 Train Loss 0.20403373 Accuracy 0.94375
# Step 60 Train Loss 0.22556865 Accuracy 0.9390625
# Step 70 Train Loss 0.37070847 Accuracy 0.8921875
# Step 80 Train Loss 0.40543932 Accuracy 0.8859375
# Step 90 Train Loss 0.31849283 Accuracy 0.909375
# Step 100 Train Loss 0.2864612 Accuracy 0.921875
# Step 110 Train Loss 0.14100158 Accuracy 0.9671875
# Step 120 Train Loss 0.35800368 Accuracy 0.8890625
# Step 130 Train Loss 0.33523542 Accuracy 0.9078125
# Step 140 Train Loss 0.34118053 Accuracy 0.9171875
# Step 150 Train Loss 0.19809337 Accuracy 0.9546875
# Step 160 Train Loss 0.24177615 Accuracy 0.93125
# Step 170 Train Loss 0.30239075 Accuracy 0.9140625
# Step 180 Train Loss 0.27651778 Accuracy 0.925
# Step 190 Train Loss 0.2805875 Accuracy 0.9125
# Step 0 Train Loss 0.42907435 Accuracy 0.871875
# Step 10 Train Loss 0.3994289 Accuracy 0.8890625
# Step 20 Train Loss 0.20608202 Accuracy 0.946875
# Step 30 Train Loss 0.3194272 Accuracy 0.909375
# Step 40 Train Loss 0.30273268 Accuracy 0.89375
# Step 50 Train Loss 0.18032731 Accuracy 0.9453125
# Step 60 Train Loss 0.18948705 Accuracy 0.940625
# Step 70 Train Loss 0.3240207 Accuracy 0.9109375
# Step 80 Train Loss 0.34173927 Accuracy 0.890625
# Step 90 Train Loss 0.28834602 Accuracy 0.9171875
# Step 100 Train Loss 0.24616022 Accuracy 0.9203125
# Step 110 Train Loss 0.12235595 Accuracy 0.965625
# Step 120 Train Loss 0.33785322 Accuracy 0.8765625
# Step 130 Train Loss 0.28919452 Accuracy 0.9203125
# Step 140 Train Loss 0.30016908 Accuracy 0.91875
# Step 150 Train Loss 0.17313942 Accuracy 0.959375
# Step 160 Train Loss 0.21582651 Accuracy 0.9375
# Step 170 Train Loss 0.29116514 Accuracy 0.915625
# Step 180 Train Loss 0.23636334 Accuracy 0.928125
# Step 190 Train Loss 0.2513229 Accuracy 0.9171875
# Dev Accuracy 0.9484375 Step 0
# Step 0 Train Loss 0.39737478 Accuracy 0.875
# Step 10 Train Loss 0.376399 Accuracy 0.8953125
# Step 20 Train Loss 0.19009663 Accuracy 0.9453125
# Step 30 Train Loss 0.27493003 Accuracy 0.91875
# Step 40 Train Loss 0.2460361 Accuracy 0.928125
# Step 50 Train Loss 0.1579722 Accuracy 0.95
# Step 60 Train Loss 0.16463336 Accuracy 0.95
# Step 70 Train Loss 0.28429928 Accuracy 0.9171875
# Step 80 Train Loss 0.30002972 Accuracy 0.896875
# Step 90 Train Loss 0.2575975 Accuracy 0.9265625
# Step 100 Train Loss 0.2152876 Accuracy 0.9296875
# Step 110 Train Loss 0.108555004 Accuracy 0.9734375
# Step 120 Train Loss 0.32790884 Accuracy 0.871875
# Step 130 Train Loss 0.24972248 Accuracy 0.925
# Step 140 Train Loss 0.25679442 Accuracy 0.9296875
# Step 150 Train Loss 0.15684843 Accuracy 0.959375
# Step 160 Train Loss 0.18916896 Accuracy 0.940625
# Step 170 Train Loss 0.2812502 Accuracy 0.9078125
# Step 180 Train Loss 0.19691388 Accuracy 0.93125
# Step 190 Train Loss 0.22934015 Accuracy 0.91875
# Step 0 Train Loss 0.36328444 Accuracy 0.8765625
# Step 10 Train Loss 0.34702066 Accuracy 0.9
# Step 20 Train Loss 0.17234746 Accuracy 0.9484375
# Step 30 Train Loss 0.23641403 Accuracy 0.9234375
# Step 40 Train Loss 0.20003979 Accuracy 0.93125
# Step 50 Train Loss 0.13941914 Accuracy 0.95625
# Step 60 Train Loss 0.1431689 Accuracy 0.959375
# Step 70 Train Loss 0.23868906 Accuracy 0.9234375
# Step 80 Train Loss 0.2603278 Accuracy 0.9
# Step 90 Train Loss 0.2263973 Accuracy 0.934375
# Step 100 Train Loss 0.18570045 Accuracy 0.934375
# Step 110 Train Loss 0.08819608 Accuracy 0.98125
# Step 120 Train Loss 0.3023572 Accuracy 0.8859375
# Step 130 Train Loss 0.21561885 Accuracy 0.9328125
# Step 140 Train Loss 0.21773326 Accuracy 0.940625
# Step 150 Train Loss 0.14423956 Accuracy 0.953125
# Step 160 Train Loss 0.16236147 Accuracy 0.953125
# Step 170 Train Loss 0.26984575 Accuracy 0.915625
# Step 180 Train Loss 0.15987548 Accuracy 0.946875
# Step 190 Train Loss 0.21654668 Accuracy 0.921875
# Dev Accuracy 0.946875 Step 0
# Step 0 Train Loss 0.33160388 Accuracy 0.884375
# Step 10 Train Loss 0.29853946 Accuracy 0.903125
# Step 20 Train Loss 0.15788187 Accuracy 0.9484375
# Step 30 Train Loss 0.20162599 Accuracy 0.9296875
# Step 40 Train Loss 0.16776145 Accuracy 0.94375
# Step 50 Train Loss 0.12480203 Accuracy 0.959375
# Step 60 Train Loss 0.12904929 Accuracy 0.9640625
# Step 70 Train Loss 0.19509545 Accuracy 0.9328125
# Step 80 Train Loss 0.22033557 Accuracy 0.9140625
# Step 90 Train Loss 0.20195302 Accuracy 0.9390625
# Step 100 Train Loss 0.16099867 Accuracy 0.940625
# Step 110 Train Loss 0.06551264 Accuracy 0.9859375
# Step 120 Train Loss 0.27577698 Accuracy 0.896875
# Step 130 Train Loss 0.18575902 Accuracy 0.946875
# Step 140 Train Loss 0.18835935 Accuracy 0.94375
# Step 150 Train Loss 0.13084933 Accuracy 0.9578125
# Step 160 Train Loss 0.13489076 Accuracy 0.9625
# Step 170 Train Loss 0.2561187 Accuracy 0.9171875
# Step 180 Train Loss 0.12753844 Accuracy 0.9640625
# Step 190 Train Loss 0.20142666 Accuracy 0.91875
# Step 0 Train Loss 0.3054982 Accuracy 0.896875
# Step 10 Train Loss 0.24916068 Accuracy 0.909375
# Step 20 Train Loss 0.1432166 Accuracy 0.946875
# Step 30 Train Loss 0.16880298 Accuracy 0.9453125
# Step 40 Train Loss 0.13769689 Accuracy 0.9484375
# Step 50 Train Loss 0.108224176 Accuracy 0.9609375
# Step 60 Train Loss 0.11701925 Accuracy 0.965625
# Step 70 Train Loss 0.15702674 Accuracy 0.9421875
# Step 80 Train Loss 0.18476005 Accuracy 0.9328125
# Step 90 Train Loss 0.17860687 Accuracy 0.9421875
# Step 100 Train Loss 0.13776577 Accuracy 0.953125
# Step 110 Train Loss 0.047000475 Accuracy 0.9890625
# Step 120 Train Loss 0.25484598 Accuracy 0.9140625
# Step 130 Train Loss 0.1623728 Accuracy 0.95
# Step 140 Train Loss 0.16385058 Accuracy 0.9578125
# Step 150 Train Loss 0.11845754 Accuracy 0.9578125
# Step 160 Train Loss 0.11189941 Accuracy 0.9671875
# Step 170 Train Loss 0.24564867 Accuracy 0.921875
# Step 180 Train Loss 0.10732789 Accuracy 0.9734375
# Step 190 Train Loss 0.18818778 Accuracy 0.93125
# Dev Accuracy 0.95 Step 0
# Step 0 Train Loss 0.29192466 Accuracy 0.8984375
# Step 10 Train Loss 0.18886003 Accuracy 0.925
# Step 20 Train Loss 0.12423237 Accuracy 0.9546875
# Step 30 Train Loss 0.13767122 Accuracy 0.9578125
# Step 40 Train Loss 0.115720235 Accuracy 0.9609375
# Step 50 Train Loss 0.09500386 Accuracy 0.96875
# Step 60 Train Loss 0.10702093 Accuracy 0.9671875
# Step 70 Train Loss 0.12229228 Accuracy 0.9578125
# Step 80 Train Loss 0.15476419 Accuracy 0.9453125
# Step 90 Train Loss 0.16757348 Accuracy 0.9421875
# Step 100 Train Loss 0.11568376 Accuracy 0.9578125
# Step 110 Train Loss 0.036697876 Accuracy 0.9921875
# Step 120 Train Loss 0.22145936 Accuracy 0.9234375
# Step 130 Train Loss 0.14121279 Accuracy 0.9578125
# Step 140 Train Loss 0.1440208 Accuracy 0.9640625
# Step 150 Train Loss 0.108951375 Accuracy 0.9640625
# Step 160 Train Loss 0.094909616 Accuracy 0.9765625
# Step 170 Train Loss 0.230616 Accuracy 0.921875
# Step 180 Train Loss 0.102323785 Accuracy 0.96875
# Step 190 Train Loss 0.16983148 Accuracy 0.9375
# Step 0 Train Loss 0.26699963 Accuracy 0.9078125
# Step 10 Train Loss 0.13753094 Accuracy 0.9484375
# Step 20 Train Loss 0.12305212 Accuracy 0.9546875
# Step 30 Train Loss 0.10759642 Accuracy 0.9734375
# Step 40 Train Loss 0.10110222 Accuracy 0.965625
# Step 50 Train Loss 0.082743935 Accuracy 0.971875
# Step 60 Train Loss 0.10730767 Accuracy 0.96875
# Step 70 Train Loss 0.09704821 Accuracy 0.971875
# Step 80 Train Loss 0.12594815 Accuracy 0.95
# Step 90 Train Loss 0.1506597 Accuracy 0.9484375
# Step 100 Train Loss 0.09384526 Accuracy 0.9640625
# Step 110 Train Loss 0.029721165 Accuracy 0.990625
# Step 120 Train Loss 0.18913771 Accuracy 0.940625
# Step 130 Train Loss 0.12572488 Accuracy 0.959375
# Step 140 Train Loss 0.12509416 Accuracy 0.9703125
# Step 150 Train Loss 0.10286264 Accuracy 0.9671875
# Step 160 Train Loss 0.08271749 Accuracy 0.98125
# Step 170 Train Loss 0.20891432 Accuracy 0.9328125
# Step 180 Train Loss 0.08236475 Accuracy 0.9734375
# Step 190 Train Loss 0.14337416 Accuracy 0.94375
# Dev Accuracy 0.946875 Step 0
# Step 0 Train Loss 0.23589773 Accuracy 0.9171875
# Step 10 Train Loss 0.118662655 Accuracy 0.9546875
# Step 20 Train Loss 0.10347664 Accuracy 0.965625
# Step 30 Train Loss 0.096301824 Accuracy 0.975
# Step 40 Train Loss 0.09333758 Accuracy 0.9703125
# Step 50 Train Loss 0.06422241 Accuracy 0.9765625
# Step 60 Train Loss 0.08218221 Accuracy 0.96875
# Step 70 Train Loss 0.07707981 Accuracy 0.9703125
# Step 80 Train Loss 0.10120567 Accuracy 0.9703125
# Step 90 Train Loss 0.13057241 Accuracy 0.95
# Step 100 Train Loss 0.08278802 Accuracy 0.9765625
# Step 110 Train Loss 0.02351794 Accuracy 0.9921875
# Step 120 Train Loss 0.15440582 Accuracy 0.9515625
# Step 130 Train Loss 0.12267499 Accuracy 0.965625
# Step 140 Train Loss 0.10847582 Accuracy 0.9734375
# Step 150 Train Loss 0.09635441 Accuracy 0.971875
# Step 160 Train Loss 0.0684585 Accuracy 0.9890625
# Step 170 Train Loss 0.19365588 Accuracy 0.9359375
# Step 180 Train Loss 0.070971 Accuracy 0.9765625
# Step 190 Train Loss 0.11708622 Accuracy 0.9515625
# Step 0 Train Loss 0.18969359 Accuracy 0.9296875
# Step 10 Train Loss 0.10919058 Accuracy 0.9609375
# Step 20 Train Loss 0.08404776 Accuracy 0.9671875
# Step 30 Train Loss 0.08968736 Accuracy 0.9765625
# Step 40 Train Loss 0.086398795 Accuracy 0.965625
# Step 50 Train Loss 0.06515178 Accuracy 0.9703125
# Step 60 Train Loss 0.06729956 Accuracy 0.9796875
# Step 70 Train Loss 0.06169495 Accuracy 0.978125
# Step 80 Train Loss 0.09964047 Accuracy 0.971875
# Step 90 Train Loss 0.102008685 Accuracy 0.9578125
# Step 100 Train Loss 0.07412775 Accuracy 0.9765625
# Step 110 Train Loss 0.02191329 Accuracy 0.9921875
# Step 120 Train Loss 0.11307625 Accuracy 0.959375
# Step 130 Train Loss 0.10040933 Accuracy 0.975
# Step 140 Train Loss 0.0962046 Accuracy 0.9734375
# Step 150 Train Loss 0.07608871 Accuracy 0.971875
# Step 160 Train Loss 0.06220243 Accuracy 0.9875
# Step 170 Train Loss 0.17492272 Accuracy 0.9390625
# Step 180 Train Loss 0.05769969 Accuracy 0.9859375
# Step 190 Train Loss 0.10703226 Accuracy 0.9609375
# Dev Accuracy 0.9421875 Step 0
# Step 0 Train Loss 0.12759933 Accuracy 0.95
# Step 10 Train Loss 0.07878117 Accuracy 0.975
# Step 20 Train Loss 0.06452769 Accuracy 0.98125
# Step 40 Train Loss 0.0028523977 Accuracy 1.0
# Step 50 Train Loss 0.0016303223 Accuracy 1.0
# Step 60 Train Loss 0.0013841694 Accuracy 1.0
# Step 70 Train Loss 0.0014196342 Accuracy 1.0
# Step 80 Train Loss 0.0012028635 Accuracy 1.0
# Step 90 Train Loss 0.0034776772 Accuracy 0.9984375
# Step 100 Train Loss 0.0024640132 Accuracy 1.0
# Step 110 Train Loss 0.001043692 Accuracy 1.0
# Step 120 Train Loss 0.0058021303 Accuracy 0.9984375
# Step 130 Train Loss 0.0036292505 Accuracy 0.9984375
# Step 140 Train Loss 0.0047453376 Accuracy 0.9984375
# Step 150 Train Loss 0.002394756 Accuracy 0.9984375
# Step 160 Train Loss 0.002479046 Accuracy 1.0
# Step 170 Train Loss 0.0038833816 Accuracy 1.0
# Step 180 Train Loss 0.0018762781 Accuracy 1.0
# Step 190 Train Loss 0.0011722978 Accuracy 1.0
# Step 0 Train Loss 0.0015647458 Accuracy 1.0
# Step 10 Train Loss 0.002344448 Accuracy 1.0
# Step 20 Train Loss 0.0007686349 Accuracy 1.0
# Step 30 Train Loss 0.0015945965 Accuracy 1.0
# Step 40 Train Loss 0.0029716932 Accuracy 1.0
# Step 50 Train Loss 0.0011780696 Accuracy 1.0
# Step 60 Train Loss 0.0012703062 Accuracy 1.0
# Step 70 Train Loss 0.0011407386 Accuracy 1.0
# Step 80 Train Loss 0.0011732251 Accuracy 1.0
# Step 90 Train Loss 0.0013898395 Accuracy 1.0
# Step 100 Train Loss 0.0010354307 Accuracy 1.0
# Step 110 Train Loss 0.0003431171 Accuracy 1.0
# Step 120 Train Loss 0.003286756 Accuracy 0.9984375
# Step 130 Train Loss 0.004270556 Accuracy 0.9984375
# Step 140 Train Loss 0.005526799 Accuracy 0.9984375
# Step 150 Train Loss 0.0009161395 Accuracy 1.0
# Step 160 Train Loss 0.0024593447 Accuracy 1.0
# Step 170 Train Loss 0.003423959 Accuracy 1.0
# Step 180 Train Loss 0.00083446584 Accuracy 1.0
# Step 190 Train Loss 0.0021177644 Accuracy 1.0
# Dev Accuracy 0.9453125 Step 0
# Step 0 Train Loss 0.0020375643 Accuracy 1.0
# Step 10 Train Loss 0.0035290346 Accuracy 0.9984375
# Step 20 Train Loss 0.00077381346 Accuracy 1.0
# Step 30 Train Loss 0.0010499076 Accuracy 1.0
# Step 40 Train Loss 0.001473825 Accuracy 1.0
# Step 50 Train Loss 0.0036781882 Accuracy 1.0
# Step 60 Train Loss 0.0017052556 Accuracy 1.0
# Step 70 Train Loss 0.0007736719 Accuracy 1.0
# Step 80 Train Loss 0.00086637185 Accuracy 1.0
# Step 90 Train Loss 0.0016341109 Accuracy 1.0
# Step 100 Train Loss 0.0010248006 Accuracy 1.0
# Step 110 Train Loss 0.0002771602 Accuracy 1.0
# Step 120 Train Loss 0.0061693215 Accuracy 0.996875
# Step 130 Train Loss 0.0006233001 Accuracy 1.0
# Step 140 Train Loss 0.004898484 Accuracy 0.9984375
# Step 150 Train Loss 0.0006013029 Accuracy 1.0
# Step 160 Train Loss 0.0030315449 Accuracy 0.9984375
# Step 170 Train Loss 0.0022618708 Accuracy 1.0
# Step 180 Train Loss 0.0007589571 Accuracy 1.0
# Step 190 Train Loss 0.0012193678 Accuracy 1.0
# Step 0 Train Loss 0.0034865174 Accuracy 0.9984375
# Step 10 Train Loss 0.0007689192 Accuracy 1.0
# Step 20 Train Loss 0.00044101587 Accuracy 1.0
# Step 30 Train Loss 0.00082849944 Accuracy 1.0
# Step 40 Train Loss 0.0011382779 Accuracy 1.0
# Step 50 Train Loss 0.0064385333 Accuracy 0.996875
# Step 60 Train Loss 0.0006972072 Accuracy 1.0
# Step 70 Train Loss 0.00069611217 Accuracy 1.0
# Step 80 Train Loss 0.0010691885 Accuracy 1.0
# Step 90 Train Loss 0.0016072007 Accuracy 1.0
# Step 100 Train Loss 0.00074152544 Accuracy 1.0
# Step 110 Train Loss 0.0003565454 Accuracy 1.0
# Step 120 Train Loss 0.008540901 Accuracy 0.996875
# Step 130 Train Loss 0.00106079 Accuracy 1.0
# Step 140 Train Loss 0.0018042816 Accuracy 1.0
# Step 150 Train Loss 0.0005377675 Accuracy 1.0
# Step 160 Train Loss 0.0021900968 Accuracy 1.0
# Step 170 Train Loss 0.0015939005 Accuracy 1.0
# Step 180 Train Loss 0.00066941045 Accuracy 1.0
# Step 190 Train Loss 0.0016502585 Accuracy 1.0
# Dev Accuracy 0.95625 Step 0
# Step 0 Train Loss 0.0018244755 Accuracy 1.0
# Step 10 Train Loss 0.00079250534 Accuracy 1.0
# Step 20 Train Loss 0.0009332822 Accuracy 1.0
# Step 30 Train Loss 0.0017700784 Accuracy 1.0
# Step 40 Train Loss 0.0008916762 Accuracy 1.0
# Step 50 Train Loss 0.016730664 Accuracy 0.996875
# Step 60 Train Loss 0.0008247776 Accuracy 1.0
# Step 70 Train Loss 0.0015273201 Accuracy 1.0
# Step 80 Train Loss 0.00093343353 Accuracy 1.0
# Step 90 Train Loss 0.0015470324 Accuracy 1.0
# Step 100 Train Loss 0.002193704 Accuracy 1.0
# Step 110 Train Loss 0.00026276434 Accuracy 1.0
# Step 120 Train Loss 0.0028998433 Accuracy 0.9984375
# Step 130 Train Loss 0.0004308697 Accuracy 1.0
# Step 140 Train Loss 0.0016996904 Accuracy 1.0
# Step 150 Train Loss 0.0003761794 Accuracy 1.0
# Step 160 Train Loss 0.0009279965 Accuracy 1.0
# Step 170 Train Loss 0.0020385007 Accuracy 1.0
# Step 180 Train Loss 0.00087944773 Accuracy 1.0
# Step 190 Train Loss 0.002641727 Accuracy 1.0
# Step 0 Train Loss 0.0014524559 Accuracy 1.0
# Step 10 Train Loss 0.0015452623 Accuracy 1.0
# Step 20 Train Loss 0.00061481656 Accuracy 1.0
# Step 30 Train Loss 0.0020265107 Accuracy 0.9984375
# Step 40 Train Loss 0.0016148525 Accuracy 1.0
# Step 50 Train Loss 0.016218962 Accuracy 0.996875
# Step 60 Train Loss 0.0007403589 Accuracy 1.0
# Step 70 Train Loss 0.005004911 Accuracy 0.9984375
# Step 80 Train Loss 0.0014584771 Accuracy 1.0
# Step 90 Train Loss 0.00064769865 Accuracy 1.0
# Step 100 Train Loss 0.001729558 Accuracy 1.0
# Step 110 Train Loss 0.0006771806 Accuracy 1.0
# Step 120 Train Loss 0.0018077346 Accuracy 1.0
# Step 130 Train Loss 0.0006931002 Accuracy 1.0
# Step 140 Train Loss 0.0013322764 Accuracy 1.0
# Step 150 Train Loss 0.0007405207 Accuracy 1.0
# Step 160 Train Loss 0.0021254905 Accuracy 1.0
# Step 170 Train Loss 0.0036057618 Accuracy 0.9984375
# Step 180 Train Loss 0.0012215549 Accuracy 1.0
# Step 190 Train Loss 0.0056361584 Accuracy 0.9984375
# Dev Accuracy 0.9484375 Step 0
# Step 0 Train Loss 0.003015124 Accuracy 1.0
# Step 10 Train Loss 0.0012022586 Accuracy 1.0
# Step 20 Train Loss 0.00060229364 Accuracy 1.0
# Step 30 Train Loss 0.002846788 Accuracy 1.0
# Step 40 Train Loss 0.0070269876 Accuracy 0.9984375
# Step 50 Train Loss 0.00055866793 Accuracy 1.0
# Step 60 Train Loss 0.0022605823 Accuracy 1.0
# Step 70 Train Loss 0.007812837 Accuracy 0.996875
# Step 80 Train Loss 0.0021155244 Accuracy 1.0
# Step 90 Train Loss 0.0012759643 Accuracy 1.0
# Step 100 Train Loss 0.0009363921 Accuracy 1.0
# Step 110 Train Loss 0.00063166127 Accuracy 1.0
# Step 120 Train Loss 0.0022649134 Accuracy 1.0
# Step 130 Train Loss 0.0011382736 Accuracy 1.0
# Step 140 Train Loss 0.0012436004 Accuracy 1.0
# Step 150 Train Loss 0.00051798124 Accuracy 1.0
# Step 160 Train Loss 0.0011380564 Accuracy 1.0
# Step 170 Train Loss 0.0027189716 Accuracy 1.0
# Step 180 Train Loss 0.0010822958 Accuracy 1.0
# Step 190 Train Loss 0.008582102 Accuracy 0.9953125
# Step 0 Train Loss 0.003771548 Accuracy 0.9984375
# Step 10 Train Loss 0.0015402903 Accuracy 1.0
# Step 20 Train Loss 0.002646827 Accuracy 1.0
# Step 30 Train Loss 0.0017401408 Accuracy 1.0
# Step 40 Train Loss 0.004993306 Accuracy 0.9984375
# Step 50 Train Loss 0.00078954996 Accuracy 1.0
# Step 60 Train Loss 0.00797544 Accuracy 0.996875
# Step 70 Train Loss 0.006870856 Accuracy 0.9984375
# Step 80 Train Loss 0.0011830273 Accuracy 1.0
# Step 90 Train Loss 0.001111923 Accuracy 1.0
# Step 100 Train Loss 0.0024341252 Accuracy 1.0
# Step 110 Train Loss 0.0006131218 Accuracy 1.0
# Step 120 Train Loss 0.007861322 Accuracy 1.0
# Step 130 Train Loss 0.0012235234 Accuracy 1.0
# Step 140 Train Loss 0.0018851726 Accuracy 1.0
# Step 150 Train Loss 0.0029332808 Accuracy 1.0
# Step 160 Train Loss 0.0010894302 Accuracy 1.0
# Step 170 Train Loss 0.0028807295 Accuracy 1.0
# Step 180 Train Loss 0.0019820475 Accuracy 1.0
# Step 190 Train Loss 0.0018864939 Accuracy 1.0
# Dev Accuracy 0.9578125 Step 0
# Step 0 Train Loss 0.005544479 Accuracy 0.996875
# Step 10 Train Loss 0.004073304 Accuracy 0.996875
# Step 20 Train Loss 0.0020233612 Accuracy 1.0
# Step 30 Train Loss 0.0011962124 Accuracy 1.0
# Step 40 Train Loss 0.009001612 Accuracy 0.9984375
# Step 50 Train Loss 0.00064226356 Accuracy 1.0
# Step 60 Train Loss 0.031037267 Accuracy 0.99375
# Step 70 Train Loss 0.0017914616 Accuracy 1.0
# Step 80 Train Loss 0.0018544535 Accuracy 1.0
# Step 90 Train Loss 0.0017356599 Accuracy 1.0
# Step 100 Train Loss 0.0018436459 Accuracy 1.0
# Step 110 Train Loss 0.0002719335 Accuracy 1.0
# Step 120 Train Loss 0.002313787 Accuracy 1.0
# Step 130 Train Loss 0.0010847951 Accuracy 1.0
# Step 140 Train Loss 0.0040140324 Accuracy 0.9984375
# Step 150 Train Loss 0.0014170666 Accuracy 1.0
# Step 160 Train Loss 0.0011503025 Accuracy 1.0
# Step 170 Train Loss 0.003608013 Accuracy 0.9984375
# Step 180 Train Loss 0.0004868515 Accuracy 1.0
# Step 190 Train Loss 0.006442886 Accuracy 0.996875
# Step 0 Train Loss 0.0016854636 Accuracy 1.0
# Step 10 Train Loss 0.0023021095 Accuracy 1.0
# Step 20 Train Loss 0.001349445 Accuracy 1.0
# Step 30 Train Loss 0.0006621333 Accuracy 1.0
# Step 40 Train Loss 0.003266062 Accuracy 1.0
# Step 50 Train Loss 0.0011863803 Accuracy 1.0
# Step 60 Train Loss 0.010333011 Accuracy 0.9953125
# Step 70 Train Loss 0.0022943025 Accuracy 1.0
# Step 80 Train Loss 0.0013065651 Accuracy 1.0
# Step 90 Train Loss 0.0030119864 Accuracy 1.0
# Step 100 Train Loss 0.0014101012 Accuracy 1.0
# Step 110 Train Loss 0.0005175364 Accuracy 1.0
# Step 120 Train Loss 0.0016395075 Accuracy 1.0
# Step 130 Train Loss 0.0033862821 Accuracy 1.0
# Step 140 Train Loss 0.0037957919 Accuracy 1.0
# Step 150 Train Loss 0.000911016 Accuracy 1.0
# Step 160 Train Loss 0.0008331705 Accuracy 1.0
# Step 170 Train Loss 0.007107972 Accuracy 0.996875
# Step 180 Train Loss 0.0006550186 Accuracy 1.0
# Step 190 Train Loss 0.004665772 Accuracy 0.9984375
# Dev Accuracy 0.95 Step 0
# Step 0 Train Loss 0.0007816801 Accuracy 1.0
# Step 10 Train Loss 0.0010748422 Accuracy 1.0
# Step 20 Train Loss 0.00077738217 Accuracy 1.0
# Step 30 Train Loss 0.0007613943 Accuracy 1.0
# Step 40 Train Loss 0.0013463013 Accuracy 1.0
# Step 50 Train Loss 0.00063655537 Accuracy 1.0
# Step 60 Train Loss 0.011692059 Accuracy 0.9953125
# Step 70 Train Loss 0.001415462 Accuracy 1.0
# Step 80 Train Loss 0.0016711585 Accuracy 1.0
# Step 90 Train Loss 0.0018132152 Accuracy 1.0
# Step 100 Train Loss 0.0007869081 Accuracy 1.0
# Step 110 Train Loss 0.00027672306 Accuracy 1.0
# Step 120 Train Loss 0.0014582605 Accuracy 1.0
# Step 130 Train Loss 0.0010524236 Accuracy 1.0
# Step 140 Train Loss 0.0009291509 Accuracy 1.0
# Step 150 Train Loss 0.00043588 Accuracy 1.0
# Step 160 Train Loss 0.0011897224 Accuracy 1.0
# Step 170 Train Loss 0.005255514 Accuracy 0.9984375
# Step 180 Train Loss 0.00045825186 Accuracy 1.0
# Step 190 Train Loss 0.0059307516 Accuracy 0.9984375
# Step 0 Train Loss 0.001090639 Accuracy 1.0
# Step 10 Train Loss 0.00053652306 Accuracy 1.0
# Step 20 Train Loss 0.00035293653 Accuracy 1.0
# Step 30 Train Loss 0.0006024565 Accuracy 1.0
# Step 40 Train Loss 0.0005802467 Accuracy 1.0
# Step 50 Train Loss 0.00023979177 Accuracy 1.0
# Step 60 Train Loss 0.0021445998 Accuracy 0.9984375
# Step 70 Train Loss 0.00024263523 Accuracy 1.0
# Step 80 Train Loss 0.00021575407 Accuracy 1.0
# Step 90 Train Loss 0.001224201 Accuracy 1.0
# Step 100 Train Loss 0.00021219463 Accuracy 1.0
# Step 110 Train Loss 0.00016403828 Accuracy 1.0
# Step 120 Train Loss 0.00030011422 Accuracy 1.0
# Step 130 Train Loss 0.00021853973 Accuracy 1.0
# Step 140 Train Loss 0.0005083144 Accuracy 1.0
# Step 150 Train Loss 0.00031392908 Accuracy 1.0
# Step 160 Train Loss 0.0012731563 Accuracy 1.0
# Step 170 Train Loss 0.001672854 Accuracy 1.0
# Step 180 Train Loss 0.0002401662 Accuracy 1.0
# Step 190 Train Loss 0.0011013069 Accuracy 1.0
# Dev Accuracy 0.95 Step 0
# Step 0 Train Loss 0.0004191774 Accuracy 1.0
# Step 10 Train Loss 0.00025040895 Accuracy 1.0
# Step 20 Train Loss 0.0002253233 Accuracy 1.0
# Step 30 Train Loss 0.00037536654 Accuracy 1.0
# Step 40 Train Loss 0.00026336993 Accuracy 1.0
# Step 50 Train Loss 0.00020071375 Accuracy 1.0
# Step 60 Train Loss 0.00091289484 Accuracy 1.0
# Step 70 Train Loss 0.00014773058 Accuracy 1.0
# Step 80 Train Loss 0.00018039672 Accuracy 1.0
# Step 90 Train Loss 0.00025011154 Accuracy 1.0
# Step 100 Train Loss 0.00023948701 Accuracy 1.0
# Step 110 Train Loss 0.00020066206 Accuracy 1.0
# Step 120 Train Loss 0.00054870464 Accuracy 1.0
# Step 130 Train Loss 0.00017945634 Accuracy 1.0
# Step 140 Train Loss 0.0006358141 Accuracy 1.0
# Step 150 Train Loss 0.00016344916 Accuracy 1.0
# Step 160 Train Loss 0.00026385073 Accuracy 1.0
# Step 170 Train Loss 0.0004910716 Accuracy 1.0
# Step 180 Train Loss 0.0003103121 Accuracy 1.0
# Step 190 Train Loss 0.00045953566 Accuracy 1.0
# Step 0 Train Loss 0.00034648282 Accuracy 1.0
# Step 10 Train Loss 0.00020198077 Accuracy 1.0
# Step 20 Train Loss 0.00014772922 Accuracy 1.0
# Step 30 Train Loss 0.00069999474 Accuracy 1.0
# Step 40 Train Loss 0.0002992542 Accuracy 1.0
# Step 50 Train Loss 0.0003061231 Accuracy 1.0
# Step 60 Train Loss 0.00028155936 Accuracy 1.0
# Step 70 Train Loss 0.00021016586 Accuracy 1.0
# Step 80 Train Loss 0.00016856323 Accuracy 1.0
# Step 90 Train Loss 0.00022811319 Accuracy 1.0
# Step 100 Train Loss 0.00018579871 Accuracy 1.0
# Step 110 Train Loss 0.000109593544 Accuracy 1.0
# Step 120 Train Loss 0.00033383397 Accuracy 1.0
# Step 130 Train Loss 0.00025307358 Accuracy 1.0
# Step 140 Train Loss 0.00030588172 Accuracy 1.0
# Step 150 Train Loss 0.00012097899 Accuracy 1.0
# Step 160 Train Loss 0.00029430483 Accuracy 1.0
# Step 170 Train Loss 0.0005548973 Accuracy 1.0
# Step 180 Train Loss 0.0002089742 Accuracy 1.0
# Step 190 Train Loss 0.0005178702 Accuracy 1.0
# Dev Accuracy 0.95 Step 0
# Step 0 Train Loss 0.0003285006 Accuracy 1.0
# Step 10 Train Loss 0.00021159454 Accuracy 1.0
# Step 20 Train Loss 9.137754e-05 Accuracy 1.0
# Step 30 Train Loss 0.000527433 Accuracy 1.0
# Step 40 Train Loss 0.00039825082 Accuracy 1.0
# Step 50 Train Loss 0.00029538907 Accuracy 1.0
# Step 60 Train Loss 0.00018618119 Accuracy 1.0
# Step 70 Train Loss 0.00023587728 Accuracy 1.0
# Step 80 Train Loss 0.00022647553 Accuracy 1.0
# Step 90 Train Loss 0.00017450459 Accuracy 1.0
# Step 100 Train Loss 0.00014615896 Accuracy 1.0
# Step 110 Train Loss 8.574099e-05 Accuracy 1.0
# Step 120 Train Loss 0.00027012167 Accuracy 1.0
# Step 130 Train Loss 0.0001992692 Accuracy 1.0
# Step 140 Train Loss 0.0002765989 Accuracy 1.0
# Step 150 Train Loss 0.00015484619 Accuracy 1.0
# Step 160 Train Loss 0.0003274277 Accuracy 1.0
# Step 170 Train Loss 0.00053063576 Accuracy 1.0
# Step 180 Train Loss 0.00016488471 Accuracy 1.0
# Step 190 Train Loss 0.00020715277 Accuracy 1.0
# Step 0 Train Loss 0.00036697398 Accuracy 1.0
# Step 10 Train Loss 0.00015119146 Accuracy 1.0
# Step 20 Train Loss 8.770064e-05 Accuracy 1.0
# Step 30 Train Loss 0.00018562247 Accuracy 1.0
# Step 40 Train Loss 0.00015287005 Accuracy 1.0
# Step 50 Train Loss 0.00016490184 Accuracy 1.0
# Step 60 Train Loss 0.0001107627 Accuracy 1.0
# Step 70 Train Loss 7.8404235e-05 Accuracy 1.0
# Step 80 Train Loss 0.00011142446 Accuracy 1.0
# Step 90 Train Loss 0.00017627142 Accuracy 1.0
# Step 100 Train Loss 0.00012277688 Accuracy 1.0
# Step 110 Train Loss 0.00015597796 Accuracy 1.0
# Step 120 Train Loss 0.00038291543 Accuracy 1.0
# Step 130 Train Loss 0.0003109267 Accuracy 1.0
# Step 140 Train Loss 0.0003823505 Accuracy 1.0
# Step 150 Train Loss 0.00016494647 Accuracy 1.0
# Step 160 Train Loss 0.0002934016 Accuracy 1.0
# Step 170 Train Loss 0.00034785856 Accuracy 1.0
# Step 180 Train Loss 0.00010523871 Accuracy 1.0
# Step 190 Train Loss 0.00020220547 Accuracy 1.0
# Dev Accuracy 0.95 Step 0
# Step 0 Train Loss 0.00035595402 Accuracy 1.0
# Step 10 Train Loss 0.00019084028 Accuracy 1.0
# Step 20 Train Loss 6.7215e-05 Accuracy 1.0
# Step 30 Train Loss 0.0001662829 Accuracy 1.0
# Step 40 Train Loss 0.00016258367 Accuracy 1.0
# Step 50 Train Loss 0.00013603093 Accuracy 1.0
# Step 60 Train Loss 6.550798e-05 Accuracy 1.0
# Step 70 Train Loss 5.982521e-05 Accuracy 1.0
# Step 80 Train Loss 9.643084e-05 Accuracy 1.0
# Step 90 Train Loss 0.00012128988 Accuracy 1.0
# Step 100 Train Loss 8.2579434e-05 Accuracy 1.0
# Step 110 Train Loss 4.2544278e-05 Accuracy 1.0
# Step 120 Train Loss 0.0006870391 Accuracy 1.0
# Step 130 Train Loss 0.00022668275 Accuracy 1.0
# Step 140 Train Loss 0.00012866428 Accuracy 1.0
# Step 150 Train Loss 0.00012117651 Accuracy 1.0
# Step 160 Train Loss 0.0001476128 Accuracy 1.0
# Step 170 Train Loss 0.0002745897 Accuracy 1.0
# Step 180 Train Loss 0.00012033982 Accuracy 1.0
# Step 190 Train Loss 0.00019591398 Accuracy 1.0
# Step 0 Train Loss 0.00020427795 Accuracy 1.0
# Step 10 Train Loss 0.000106826286 Accuracy 1.0
# Step 20 Train Loss 6.446059e-05 Accuracy 1.0
# Step 30 Train Loss 0.00013354076 Accuracy 1.0
# Step 40 Train Loss 0.00010510788 Accuracy 1.0
# Step 50 Train Loss 9.905605e-05 Accuracy 1.0
# Step 60 Train Loss 5.641954e-05 Accuracy 1.0
# Step 70 Train Loss 6.1481005e-05 Accuracy 1.0
# Step 80 Train Loss 8.94728e-05 Accuracy 1.0
# Step 90 Train Loss 9.604146e-05 Accuracy 1.0
# Step 100 Train Loss 7.18228e-05 Accuracy 1.0
# Step 110 Train Loss 4.117321e-05 Accuracy 1.0
# Step 120 Train Loss 0.0017030475 Accuracy 0.9984375
# Step 130 Train Loss 9.523228e-05 Accuracy 1.0
# Step 140 Train Loss 0.00012860775 Accuracy 1.0
# Step 150 Train Loss 6.391883e-05 Accuracy 1.0
# Step 160 Train Loss 0.00021561491 Accuracy 1.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-105-fbd2c87f491e> in <module>
#       6         sess.run(train_initializer)
#       7         for step in range(200):
# ----> 8             loss, acc, _ = sess.run([cross_entropy, accuracy, train])
#       9             # Print log
#      10             if step % 10 == 0:
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     948     try:
#     949       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 950                          run_metadata_ptr)
#     951       if run_metadata:
#     952         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1171     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1172       results = self._do_run(handle, final_targets, final_fetches,
# -> 1173                              feed_dict_tensor, options, run_metadata)
#    1174     else:
#    1175       results = []
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1348     if handle is None:
#    1349       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1350                            run_metadata)
#    1351     else:
#    1352       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1354   def _do_call(self, fn, *args):
#    1355     try:
# -> 1356       return fn(*args)
#    1357     except errors.OpError as e:
#    1358       message = compat.as_text(e.message)
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1339       self._extend_graph()
#    1340       return self._call_tf_sessionrun(
# -> 1341           options, feed_dict, fetch_list, target_list, run_metadata)
#    1342
#    1343     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1427     return tf_session.TF_SessionRun_wrapper(
#    1428         self._session, options, feed_dict, fetch_list, target_list,
# -> 1429         run_metadata)
#    1430
#    1431   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
